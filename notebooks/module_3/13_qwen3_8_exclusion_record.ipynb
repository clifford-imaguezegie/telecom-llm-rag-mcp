# %% [markdown]
# # **Notebook 13 — Module 3 Qwen3.8 Flash Exclusion Record**
#
# ## **Purpose**
# Document the attempted Qwen3.8 Flash participation in the frozen **Module 3 Evaluation Benchmark v2** and preserve the reason it was excluded from scored cross-LLM comparison.
#
# This notebook is a **documentation record**, not a scored benchmark notebook. It intentionally does not rerun the provider call.

# %% [markdown]
# ## **Frozen evaluation status**
#
# - **Model:** Qwen3.8 Flash
# - **Access path:** OpenRouter shared Alibaba capacity
# - **Benchmark:** Module 3 Evaluation Benchmark v2
# - **Final status:** **EXCLUDED**
# - **Observed blocker:** repeated upstream provider `HTTP 429` rate limiting before a valid MCP benchmark execution could be completed.
#
# ### **Interpretation**
#
# Qwen3.8 Flash is **not scored as a model failure, MCP failure or retrieval failure**. The exclusion reflects an external provider-availability constraint during the frozen evaluation window.
#
# > **Canonical wording:** Qwen3.8 Flash was excluded from the final Benchmark v2 comparison because repeated execution was blocked by upstream provider rate limiting (HTTP 429) through OpenRouter's shared Alibaba capacity. The exclusion reflects an external availability constraint rather than model or MCP-system performance.

# %% [markdown]
# ## **Evaluation rule**
#
# The other eight scored experiments comprise four LLMs across Version A and Version B. Qwen is retained transparently as an availability observation but is excluded from ranking, completion-rate denominators and architecture/model scorecards.
#
# No post-hoc substitution, provider switch or rerun was introduced because that would change the frozen comparison conditions.
